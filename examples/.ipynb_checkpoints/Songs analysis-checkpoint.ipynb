# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/mehdi/Downloads/songs/feats.ssd",header=None )

# %%
df2 = df.iloc[[1]]

# %%
X = df.as_matrix()[:,1:]

# %%
X
# Out:
# array([[4.61118373541, 6.903247597439999, 6.71173715356, ...,
#         6.62847566788, 3.7505573215099997, 0.647791636588],
#        [5.5000698097, 7.98481612976, 7.777990086900001, ...,
#         6.857779762840001, 4.28740102132, 0.7686619383759999],
#        [5.607099043180001, 8.610889105010001, 7.85481668418, ...,
#         6.40268467968, 3.69682953771, 0.651753599228],
#        ...,
#        [4.16206735259, 6.160592100720001, 6.075868020720001, ...,
#         6.41339808428, 4.00336062885, 0.717927284938],
#        [5.17310245098, 6.82835933231, 5.75097293267, ..., 6.52829608424,
#         3.6157164017300003, 0.622007671705],
#        [5.19735617365, 7.03335514623, 6.616800951139999, ...,
#         6.41653153941, 3.97816410297, 0.722943427078]], dtype=object)

# %%
cd /Users/mehdi/Dropbox/working\ folder
# Out:
# /Users/mehdi/Dropbox/working folder

# %%
cd PHd/phd-clustering-models/
# Out:
# /Users/mehdi/Dropbox/working folder/PHd/phd-clustering-models

# %%
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tools.viz_bench_tools_2 import *
from K_estim_pi_pen_EM import GraphLassoMix

# %%
a = Benchmark(None, lambda_param_list = [50], max_clusters=4, n_algo_iter=10)
b= a.algo_eval(GraphLassoMix, X)
# Out:
# -----------------------------------------
# Param Lambda = 50
# Max clusters:  4
# Nombre d'iterations FISTA:  200
# Algo Iteration:  0
# [ 0.14863333  0.54863333  0.08196667  0.26696667]
# [ 0.15237513  0.55238124  0.08570069  0.25572988]
# [ 0.15611243  0.55613034  0.08942367  0.24451077]
# [ 0.15984481  0.55987984  0.09313617  0.23330987]
# [ 0.16357186  0.56362896  0.09683862  0.22212793]
# [ 0.16729312  0.56737693  0.10053125  0.21096598]
# [ 0.17100812  0.57112296  0.10421418  0.19982532]
# [ 0.17471632  0.57486625  0.10788735  0.18870757]
# [ 0.17841709  0.57860591  0.11155057  0.17761476]
# [ 0.18210971  0.58234098  0.11520348  0.16654941]
# [ 0.18579334  0.5860704   0.11884554  0.15551465]
# [ 0.18946693  0.58979291  0.12247597  0.14451438]
# [ 0.19312922  0.59350707  0.12609374  0.13355355]
# [ 0.19677864  0.59721112  0.12969748  0.12263849]
# [ 0.20041319  0.6009029   0.13328537  0.11177741]
# [ 0.20403032  0.60457968  0.13685501  0.10098123]
# ...

# %%
from sklearn.mixture import GMM

# %%
cl = GMM(n_components=6)

# %%
cl.fit_predict(X)
# Out:
# array([0, 4, 0, 0, 4, 1, 1, 2, 2, 1, 2, 1, 5, 1, 0, 4, 2, 2, 1, 4, 2, 1, 2,
#        1, 2, 2, 0, 1, 2, 1, 1, 1, 1, 3, 1, 2, 2, 2, 4, 1])

# %%
cl.means_
# Out:
# array([[ 0.02051701,  0.02492755,  0.02155636, ...,  0.01598912,
#          0.01052962,  0.00226563],
#        [ 0.02027616,  0.02494872,  0.02489879, ...,  0.01271968,
#          0.00806243,  0.00165199],
#        [ 0.02993207,  0.03191296,  0.02534563, ...,  0.02622807,
#          0.01613272,  0.00315325],
#        [ 0.02980139,  0.02638066,  0.02754406, ...,  0.04636796,
#          0.02530894,  0.00498537],
#        [ 0.02678266,  0.03000039,  0.02434684, ...,  0.02742034,
#          0.0166939 ,  0.00344853],
#        [ 0.01684   ,  0.02008604,  0.01998546, ...,  0.01613901,
#          0.0123546 ,  0.00236759]])

# %%
zip(df.as_matrix()[:,0],df["cluster"])
# Out:
# [('01.CharliePuth-MarvinGaye(Feat.MeghanTrainor).mp3', 0),
#  ('02.CalvinHarris+Disciples-HowDeepIsYourLove.mp3', 3),
#  ("03.TheWeeknd-Can'tFeelMyFace.mp3", 0),
#  ('04.LittleMix-BlackMagic.mp3', 0),
#  ('05.LostFrequencies-AreYouWithMe.mp3', 3),
#  ('06.Sigma-Glitterball(Feat.EllaHenderson).mp3', 9),
#  ('07.Years&Years-Shine.mp3', 0),
#  ('08.WALKTHEMOON-ShutUpandDance.mp3', 2),
#  ('09.OneDirection-DragMeDown.mp3', 9),
#  ('10.OMI-Cheerleader(FelixJaehnRemix).mp3', 1),
#  ('11.MajorLazer&DJSnake-LeanOn(Feat.MO).mp3', 5),
#  ('12.SamFeldt-ShowMeLove(Feat.KimberlyAnne).mp3', 1),
#  ('13.Disclosure-Omen(Feat.SamSmith).mp3', 0),
#  ('14.Avicii-WaitingforLove.mp3', 2),
#  ('15.JasonDerulo-WanttoWantMe.mp3', 0),
#  ('16.DavidZowie-HouseEveryWeekend(RadioEdit).mp3', 3),
#  ('17.TinieTempah-NotLettingGo(Feat.JessGlynne).mp3', 4),
#  ('18.FettyWap-TrapQueen.mp3', 6),
#  ('19.EdSheeran-Photograph.mp3', 1),
#  ('20.JoeStone-TheParty(ThisIsHowWeDoIt)(Feat.MontellJordan).mp3', 7),
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X2 = sc.fit_transform(X)
# Out:
# /usr/local/lib/python2.7/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /usr/local/lib/python2.7/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
sc.
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
